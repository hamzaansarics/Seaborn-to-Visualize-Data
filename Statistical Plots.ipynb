# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'I:\Text Datasets\CSV\ted.csv')
# sns.set(style='whitegrid')
plt.style.use('fivethirtyeight')

# %%
df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %% [markdown]
# #### Line Plot
# - This is simple line plot wihch tell shows the relationship between two variables which may be linear or non linear relationship

# %%
fig=plt.figure(figsize=(10,4),facecolor='w',edgecolor='k')
sns.set(style='darkgrid')
plt.title('Simple Seaborn Line Plot')
plt.xlabel('CATEGORY*')
plt.ylabel('MILES*')

ax.axhline(10)
ax.grid(False)
sns.lineplot('duration','comments',data=df)


plt.show()

# %% [markdown]
# #### Scatter Plot
# - This is also a simple scatter graph which will show the relationship between two variables which may be linear or non linear relationship

# %%
fig=plt.figure(figsize=(10,4))
plt.title('Simple Scatter Graph')
sns.scatterplot('duration','comments',data=df)
plt.show()
